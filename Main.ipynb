# %%
class car:
    def definiation(self,shape_type,colour,size):
        self.shape_type = shape_type
        self.colour = colour
        self.size = size

class Mahindra(car):
    def definiation(self, shape_type, colour, size):
        return super().definiation(shape_type, colour, size)

# %%
ZzzZ
